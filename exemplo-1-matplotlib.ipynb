# %% [markdown]
# # Importações

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Criação do dataset

# %%
from sklearn.datasets import make_regression
# 200 amostras de 1 feature, 30 dessas amostras são ruído.
x, y = make_regression(n_samples=200, n_features=1, noise=30)

# %% [markdown]
# # Gráficos

# %%
plt.scatter(x,y)
plt.show()
